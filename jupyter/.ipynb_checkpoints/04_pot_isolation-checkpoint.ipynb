# %%
import tifffile as tf
import numpy as np
import pandas as pd
import numpy.polynomial.polynomial as P
import scipy.spatial as spatial
import scipy.ndimage as ndimage
from importlib import reload

import arabidopsis_utils as thales
import MinimumBoundingBox as mbb

# %% [markdown]
# # Get 4 pots

# %%
tiff_file = '../raw3d/col-0.tif'

dst = 
norm_src = '../normalization/vals/'

src, fname = os.path.split(tiff_file)
bname = os.path.splitext(fname)[0]
img = tf.imread(tiff_file)

# %%
writefig = False
display  = True
diag_dst = src
snaps = vitaminC.collapse_dimensions(pots)
vitaminC.plot_collapse_dimensions(snaps, bname, 'rind', display=display, writefig=writefig, dst=diag_dst)

# %%
pts = snaps[0].copy()
pts = (255*pts/np.max(pts)).astype(np.uint8).reshape(snaps[0].shape)
pts[pts < 70] = 0
pts[pts > 0] = 1
border = np.array([[-1, -1, -1],
                   [-1, 8, -1],
                   [-1, -1, -1]])

surface = ndimage.convolve(pts, border, np.int8, 'constant', cval=0)
surface[ surface < 0 ] = 0
surface = surface.astype(np.uint8)
surface[ surface > 0 ] = 1

# %%
plt.figure(figsize=(10,10))
plt.imshow(surface, cmap='inferno', origin='lower');
#plt.plot(rect[hull.vertices,1], rect[hull.vertices,0], 'y--', lw=2);
#plt.plot(rhull[:,1], rhull[:,0], 'y--', lw=3);

# %%
scoords = vitaminC.tiff2coords(surface, False)

# %%
bbox = mbb.MinimumBoundingBox(scoords)

rect = np.array(list(bbox.corner_points))
mincoord = np.min(rect, axis=0)
maxcoord = np.max(rect, axis=0)

print(rect)
print(maxcoord)
rect[int(np.argwhere(rect[:,1] == mincoord[1])[0]), :]
# Out:
# [[1790.99730142 1275.5769986 ]
#  [1284.58372751   22.97852601]
#  [ 528.33431088 1786.05956078]
#  [  21.92073697  533.46108819]]
# [1790.99730142 1786.05956078]
# array([1284.58372751,   22.97852601])

# %%
def four_corners(boundary):
    coords = np.nonzero(boundary)
    coords = np.column_stack((coords[0], coords[1]))
    bbox = mbb.MinimumBoundingBox(coords)
    
    rect = np.array(list(bbox.corner_points))
    mincoord = np.min(rect, axis=0)
    maxcoord = np.max(rect, axis=0)
    
    tmost = rect[int(np.argwhere(rect[:,0] == maxcoord[0])[0]), :]
    rmost = rect[int(np.argwhere(rect[:,1] == maxcoord[1])[0]), :]
    
    bmost = rect[int(np.argwhere(rect[:,0] == mincoord[0])[0]), :]
    lmost = rect[int(np.argwhere(rect[:,1] == mincoord[1])[0]), :]
    
    return np.array([tmost, rmost, bmost, lmost])

# %%
corners = four_corners(surface)
tpt, rpt, bpt, lpt = corners
center = np.mean(corners,axis=0)
print(tpt, rpt, bpt, lpt, sep='\n')
# Out:
# [1790.99730142 1275.5769986 ]
# [ 528.33431088 1786.05956078]
# [ 21.92073697 533.46108819]
# [1284.58372751   22.97852601]

# %%
rhull = np.vstack((lpt,tpt,rpt,bpt,lpt))

# %%
def four_borderlines(corners):
    coefs = np.empty((len(corners), corners.ndim))
    
    for i in range(len(corners)):
        j = (i+1)%len(corners)
        
        line = np.vstack((corners[i,:], corners[j,:]))
        poly_fit = P.Polynomial.fit(line[:,1] , line[:,0], deg=1, full=False )
        coefs[i,:] = poly_fit.convert().coef
    
    return coefs

# %%
bcoefs = four_borderlines(corners)
bcoefs
# Out:
# array([[ 4.94609796e+03, -2.47346939e+00],
#        [-1.93752475e+02,  4.04290429e-01],
#        [ 1.34142041e+03, -2.47346939e+00],
#        [ 1.27529373e+03,  4.04290429e-01]])

# %%
def four_midpoints(corners):
    midpoints = np.empty((len(corners), corners.ndim))
    
    for i in range(len(corners)):
        j = (i+1)%len(corners)
        
        midpoints[i,:] = (corners[i,:] + corners[j,:])/2
    return midpoints

# %%
midpoints = four_midpoints(corners)
midpoints
# Out:
# array([[1159.66580615, 1530.81827969],
#        [ 275.12752393, 1159.76032449],
#        [ 653.25223224,  278.2198071 ],
#        [1537.79051446,  649.2777623 ]])

# %%
def midline_splits(midpoints):
    splits = np.empty((int(len(midpoints)/2), midpoints.ndim))
    for i in range(len(splits)):
        j = (i+2)%len(midpoints)
        
        line = np.vstack((midpoints[i,:], midpoints[j,:]))
        poly_fit = P.Polynomial.fit(line[:,1] , line[:,0], deg=1, full=False )
        splits[i,:] = poly_fit.convert().coef
    
    return splits

# %%
mcoefs = midline_splits(midpoints)
mcoefs
# Out:
# array([[ 5.40770627e+02,  4.04290429e-01],
#        [ 3.14375918e+03, -2.47346939e+00]])

# %%
def four_centers(corners, midpoints):
    center = np.mean(corners,axis=0)
    centers = np.empty((len(corners), corners.ndim))
    
    for i in range(len(corners)):
        j = (i-1)%len(corners)
        pts = np.vstack((center, corners[i,:], midpoints[i,:], midpoints[j,:]))
        centers[i,:] = np.mean(pts, axis=0)
    
    return centers

# %%
centers = four_centers(corners, midpoints)
centers
# Out:
# array([[1348.7281603 , 1090.048021  ],
#        [ 717.39666504, 1345.28930209],
#        [ 464.18987808,  718.99006579],
#        [1095.52137335,  463.7487847 ]])

# %%
plt.figure(figsize=(10,10))
plt.imshow(surface, cmap='inferno', origin='lower');
for i in range(len(bcoefs)):
    plt.axline(corners[i,:][::-1], slope=bcoefs[i,1], c='y', lw=3)
    plt.plot(corners[i,1], corners[i,0], 'yo', ms=20)
    plt.plot(centers[i,1], centers[i,0], 'cX', ms=15)
    plt.plot(midpoints[i,1], midpoints[i,0], 'gh', ms=15)
for i in range(len(mcoefs)):
    plt.axline(midpoints[i,:][::-1], slope=mcoefs[i,1], c='g', lw=3)

plt.plot(center[1], center[0], 'mD', ms=15);
#plt.savefig('split_pots.jpg', dpi=150, pil_kwargs={'optimize':True})

# %%
foo = midpoints - center
bar = np.sqrt(np.sum(foo**2, axis=1)).reshape(foo.shape[0],1)
WS = foo/bar
WS
# Out:
# array([[ 0.37481715,  0.92709875],
#        [-0.92709875,  0.37481715],
#        [-0.37481715, -0.92709875],
#        [ 0.92709875, -0.37481715]])

# %%
bs = bcoefs[:,0]/(bcoefs[:,1]*WS[:,1] - WS[:,0])
bs
# Out:
# array([-1853.8823576 ,  -179.62767858,   502.78737893, -1182.32322875])

# %%
foo = midpoints[np.array([2,1]), :] - corners[2,:]
bar = np.sqrt(np.sum(foo**2, axis=1)).reshape(foo.shape[0],1)
ZS = foo/bar
ZS
# Out:
# array([[ 0.92709875, -0.37481715],
#        [ 0.37481715,  0.92709875]])

# %%
cs = mcoefs[:,0]/(mcoefs[:,1]*ZS[:,1] - ZS[:,0])
cs
# Out:
# array([ -501.34777508, -1178.33486826])

# %%
filename = src + bname + '_2d_measurements.csv'

columns = ['cornerX', 'cornerY',
           'border_int', 'border_slope',
           'midpointX', 'midpointY',
           'centersX', 'centersY',
           'WX', 'WY', 'b']

index = ['tmost', 'rmost', 'bmost', 'lmost']

pd.DataFrame(np.column_stack((corners, bcoefs, midpoints, centers, WS, bs)), 
             columns=columns, index=index).to_csv(filename)

# %%
filename = src + bname + '_2d_measurements_supp.csv'

columns = ['mid_int', 'mid_slope', 'ZX', 'ZY', 'c']

index = ['horz', 'vert']

pd.DataFrame(np.column_stack((mcoefs, ZS, cs)),
             columns=columns, index=index).to_csv(filename)

# %% [markdown]
# # Go to 3D

# %%
coords = vitaminC.tiff2coords(pots, False)
print(coords.shape) #84.9M
# Out:
# (30319215, 3)

# %%
W3D = np.column_stack((np.zeros(len(WS)), WS))
Z3D = np.column_stack((np.zeros(len(ZS)), ZS))
potwidth = 0

# %%
orientation = np.full((len(coords), len(W3D)), False, dtype=np.bool)

for i in range(len(W3D)):
    W = W3D[i, :]
    b = bs[i]

    orientation[:, i] = np.sum(coords*W, axis=1) + b < -potwidth

# %%
coords = coords[np.sum(orientation, axis=1) == len(W3D),:]

# %%
orientation = np.full((len(coords), len(Z3D)), False, dtype=np.bool)

for i in range(len(Z3D)):
    W = Z3D[i, :]
    b = cs[i]

    orientation[:, i] = np.sum(coords*W, axis=1) + b < 0

# %%
potcoords = coords[np.sum(orientation, axis=1) == len(Z3D), :]
print(potcoords.shape)

new_mask = np.empty_like(pots)
new_mask[potcoords[:,0], potcoords[:,1], potcoords[:,2]] = True

pot3 = new_mask*pots
snaps3 = vitaminC.collapse_dimensions(pot3)
# Out:
# (6922110, 3)

# %%
orientation = np.full((len(coords), len(Z3D)), False, dtype=np.bool)

for i in range(len(Z3D)):
    W = Z3D[i, :]
    b = cs[i]

    orientation[:, i] = np.sum(coords*W, axis=1) + b < potwidth

# %%
potcoords = coords[np.sum(orientation, axis=1) == 0, :]
print(potcoords.shape)

new_mask = np.empty_like(pots)
new_mask[potcoords[:,0], potcoords[:,1], potcoords[:,2]] = True

pot0 = new_mask*pots
snaps0 = vitaminC.collapse_dimensions(pot0)
# Out:
# (8889230, 3)

# %%
orientation = np.full((len(coords), len(Z3D)), False, dtype=np.bool)

i=0
W = Z3D[i, :]
b = cs[i]
orientation[:, i] = np.sum(coords*W, axis=1) + b < potwidth

i=1
W = Z3D[i, :]
b = cs[i]
orientation[:, i] = np.sum(coords*W, axis=1) + b < -potwidth

# %%
potcoords = coords[(np.sum(orientation, axis=1) == 1) & (orientation[:,1]), :]
print(potcoords.shape)

new_mask = np.empty_like(pots)
new_mask[potcoords[:,0], potcoords[:,1], potcoords[:,2]] = True

pot2 = new_mask*pots
snaps2 = vitaminC.collapse_dimensions(pot2)
# Out:
# (7231185, 3)

# %%
orientation = np.full((len(coords), len(Z3D)), False, dtype=np.bool)

i=1
W = Z3D[i, :]
b = cs[i]
orientation[:, i] = np.sum(coords*W, axis=1) + b < potwidth

i=0
W = Z3D[i, :]
b = cs[i]
orientation[:, i] = np.sum(coords*W, axis=1) + b < -potwidth

# %%
potcoords = coords[(np.sum(orientation, axis=1) == 1) & (orientation[:,0]), :]
print(potcoords.shape)

new_mask = np.empty_like(pots)
new_mask[potcoords[:,0], potcoords[:,1], potcoords[:,2]] = True

pot1 = new_mask*pots
snaps1 = vitaminC.collapse_dimensions(pot1)
# Out:
# (6202841, 3)

# %%
fig, ax = plt.subplots(2,2, figsize=(15,15))

ax[0,0].imshow(snaps0[0], cmap='inferno', origin='lower');
ax[0,1].imshow(snaps1[0], cmap='inferno', origin='lower');
ax[1,0].imshow(snaps2[0], cmap='inferno', origin='lower');
ax[1,1].imshow(snaps3[0], cmap='inferno', origin='lower');

fig.tight_layout()
plt.savefig('separated_pots_4.jpg', dpi=150, pil_kwargs={'optimize':True})

# %%
src = 'arabidopsis/'
bname = 'col0'

tf.imwrite(src + 'pot0-' + bname + '.tif', pot0 , photometric='minisblack',compress=3)
tf.imwrite(src + 'pot1-' + bname + '.tif', pot1 , photometric='minisblack',compress=3)
tf.imwrite(src + 'pot2-' + bname + '.tif', pot2 , photometric='minisblack',compress=3)
tf.imwrite(src + 'pot3-' + bname + '.tif', pot3 , photometric='minisblack',compress=3)
